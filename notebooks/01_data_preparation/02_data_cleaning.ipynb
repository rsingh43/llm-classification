# %% [markdown]
# # 02_data_cleaning
#
# The dataset appears to be well-structured and free from common quality issues. It appears that the only potential issue is the presence of missing values.
#
# Since there are no other apparent problems, no additional cleaning steps are necessary at this stage beyond handling the missing data.

# %% [markdown]
# # Imports

# %%
import sys

import pandas as pd

sys.path.append("../../src")
import GiveMeSomeCredit

# %% [markdown]
# # Data Files

# %% [markdown]
# ## `cs-training.csv`

# %%
df = GiveMeSomeCredit.load_training_data()
# Out:
# /Users/rina/llm-classification/data/GiveMeSomeCredit/raw/cs-training.csv Memory Usage: 13.73 MB
#                                         dtype   count  non_null  null_count  \
# SeriousDlqin2yrs                        int64  150000    150000           0
# RevolvingUtilizationOfUnsecuredLines  float64  150000    150000           0
# age                                     int64  150000    150000           0
# NumberOfTime30-59DaysPastDueNotWorse    int64  150000    150000           0
# DebtRatio                             float64  150000    150000           0
# MonthlyIncome                         float64  120269    120269       29731
# NumberOfOpenCreditLinesAndLoans         int64  150000    150000           0
# NumberOfTimes90DaysLate                 int64  150000    150000           0
# NumberRealEstateLoansOrLines            int64  150000    150000           0
# NumberOfTime60-89DaysPastDueNotWorse    int64  150000    150000           0
# ...

# %% [markdown]
# ## `cs-test.csv`

# %%
df = GiveMeSomeCredit.load_testing_data()
# Out:
# /Users/rina/llm-classification/data/GiveMeSomeCredit/raw/cs-test.csv Memory Usage: 9.29 MB
#                                         dtype   count  non_null  null_count  \
# SeriousDlqin2yrs                      float64       0         0      101503
# RevolvingUtilizationOfUnsecuredLines  float64  101503    101503           0
# age                                     int64  101503    101503           0
# NumberOfTime30-59DaysPastDueNotWorse    int64  101503    101503           0
# DebtRatio                             float64  101503    101503           0
# MonthlyIncome                         float64   81400     81400       20103
# NumberOfOpenCreditLinesAndLoans         int64  101503    101503           0
# NumberOfTimes90DaysLate                 int64  101503    101503           0
# NumberRealEstateLoansOrLines            int64  101503    101503           0
# NumberOfTime60-89DaysPastDueNotWorse    int64  101503    101503           0
# ...

# %% [markdown]
# ## `sampleEntry.csv`

# %%
df = GiveMeSomeCredit.load_sample_entry_data()
# Out:
# /Users/rina/llm-classification/data/GiveMeSomeCredit/raw/sampleEntry.csv Memory Usage: 1.55 MB
#                dtype   count  non_null  null_count      mean       std  \
# Probability  float64  101503    101503           0  0.067664  0.110445
#
#                   min       25%       50%       75%       max
# Probability  0.003513  0.011705  0.023285  0.067193  0.826056
#         Probability
# Id
# 1          0.080807
# 2          0.040719
# 3          0.011968
# 4          0.067640
# 5          0.108264
# ...             ...
# 101499     0.045363
# 101500     0.343775
# 101501     0.006970
# 101502     0.121994
# 101503     0.044248
#
# [101503 rows x 1 columns]

# %% [markdown]
# ## `Data Dictionary.xls`

# %%
df = GiveMeSomeCredit.load_data_dictionary()
# Out:
# <h1>Sheet1</h1>
# Sheet1 Memory Usage: 0.00 MB
#               dtype  count  non_null  null_count unique  \
# Description  object     11        11           0     11
# Type         object     11        11           0      4
#
#                                                            top freq
# Description  Person experienced 90 days past due delinquenc...    1
# Type                                                   integer    7
#                                                                             Description  \
# Variable Name
# SeriousDlqin2yrs                      Person experienced 90 days past due delinquenc...
# RevolvingUtilizationOfUnsecuredLines  Total balance on credit cards and personal lin...
# age                                                            Age of borrower in years
# NumberOfTime30-59DaysPastDueNotWorse  Number of times borrower has been 30-59 days p...
# DebtRatio                             Monthly debt payments, alimony,living costs di...
# ...
