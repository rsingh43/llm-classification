# %% [markdown]
# # Imports

# %%
import sys

import dotenv
import pandas as pd

from IPython.display import display, HTML

dotenv.load_dotenv()
sys.path.append("../../src")
import dataframe_utils
import GiveMeSomeCredit

# %% [markdown]
# # Variables

# %% [markdown]
# # Load the Dataset
#
# This section loads the LLM text classification data into a DataFrame and displays its basic information.

# %%
responses_df = GiveMeSomeCredit.load_classification_responses()

with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(
        dataframe_utils.describe_df(responses_df)
    )

with pd.option_context("display.max_colwidth", None):
    display(
        responses_df.head(5).style.set_properties(**{"text-align": "left"})
    )
    
print(responses_df["Prediction"].value_counts())
# Out:
#                               dtype  count  non_null  null_count unique  \
# Row ID                        int64  90000     90000           0    NaN
# Model                        object  90000     90000           0      1
# Description Column            int64  90000     90000           0    NaN
# Classification Question ID    int64  90000     90000           0    NaN
# Prediction                   object  90000     90000           0      3
# Yes Probability             float64  90000     90000           0    NaN
# No Probability              float64  90000     90000           0    NaN
#
#                                              top   freq       mean  \
# Row ID                                       NaN    NaN  74548.148
# Model                       google/flan-t5-small  90000        NaN
# Description Column                           NaN    NaN        0.0
# Classification Question ID                   NaN    NaN        1.0
# Prediction                                    no  61479        NaN
# Yes Probability                              NaN    NaN   0.373138
# No Probability                               NaN    NaN   0.461125
#
#                                      std       min       25%       50%  \
# Row ID                      43327.774348       4.0  36814.25   74261.0
# Model                                NaN       NaN       NaN       NaN
# Description Column                   0.0       0.0       0.0       0.0
# Classification Question ID      0.816501       0.0       0.0       1.0
# Prediction                           NaN       NaN       NaN       NaN
# Yes Probability                 0.080088  0.169391  0.273927   0.41593
# No Probability                  0.155254  0.136118  0.255221  0.558641
#
#                                   75%       max
# Row ID                      111940.25  149993.0
# Model                             NaN       NaN
# Description Column                0.0       0.0
# Classification Question ID        2.0       2.0
# Prediction                        NaN       NaN
# Yes Probability              0.435758  0.495583
# No Probability               0.577702  0.611146
# <style type="text/css">
# #T_21ee7_row0_col0, #T_21ee7_row0_col1, #T_21ee7_row0_col2, #T_21ee7_row0_col3, #T_21ee7_row0_col4, #T_21ee7_row0_col5, #T_21ee7_row0_col6, #T_21ee7_row1_col0, #T_21ee7_row1_col1, #T_21ee7_row1_col2, #T_21ee7_row1_col3, #T_21ee7_row1_col4, #T_21ee7_row1_col5, #T_21ee7_row1_col6, #T_21ee7_row2_col0, #T_21ee7_row2_col1, #T_21ee7_row2_col2, #T_21ee7_row2_col3, #T_21ee7_row2_col4, #T_21ee7_row2_col5, #T_21ee7_row2_col6, #T_21ee7_row3_col0, #T_21ee7_row3_col1, #T_21ee7_row3_col2, #T_21ee7_row3_col3, #T_21ee7_row3_col4, #T_21ee7_row3_col5, #T_21ee7_row3_col6, #T_21ee7_row4_col0, #T_21ee7_row4_col1, #T_21ee7_row4_col2, #T_21ee7_row4_col3, #T_21ee7_row4_col4, #T_21ee7_row4_col5, #T_21ee7_row4_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_21ee7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21ee7_level0_col0" class="col_heading level0 col0" >Row ID</th>
#       <th id="T_21ee7_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_21ee7_level0_col2" class="col_heading level0 col2" >Description Column</th>
#       <th id="T_21ee7_level0_col3" class="col_heading level0 col3" >Classification Question ID</th>
#       <th id="T_21ee7_level0_col4" class="col_heading level0 col4" >Prediction</th>
#       <th id="T_21ee7_level0_col5" class="col_heading level0 col5" >Yes Probability</th>
#       <th id="T_21ee7_level0_col6" class="col_heading level0 col6" >No Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21ee7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21ee7_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_21ee7_row0_col1" class="data row0 col1" >google/flan-t5-small</td>
#       <td id="T_21ee7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_21ee7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_21ee7_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_21ee7_row0_col5" class="data row0 col5" >0.248806</td>
#       <td id="T_21ee7_row0_col6" class="data row0 col6" >0.226628</td>
#     </tr>
#     <tr>
#       <th id="T_21ee7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21ee7_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_21ee7_row1_col1" class="data row1 col1" >google/flan-t5-small</td>
#       <td id="T_21ee7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_21ee7_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_21ee7_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_21ee7_row1_col5" class="data row1 col5" >0.266791</td>
#       <td id="T_21ee7_row1_col6" class="data row1 col6" >0.234390</td>
#     </tr>
#     <tr>
#       <th id="T_21ee7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21ee7_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_21ee7_row2_col1" class="data row2 col1" >google/flan-t5-small</td>
#       <td id="T_21ee7_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_21ee7_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_21ee7_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_21ee7_row2_col5" class="data row2 col5" >0.224461</td>
#       <td id="T_21ee7_row2_col6" class="data row2 col6" >0.160168</td>
#     </tr>
#     <tr>
#       <th id="T_21ee7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21ee7_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_21ee7_row3_col1" class="data row3 col1" >google/flan-t5-small</td>
#       <td id="T_21ee7_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_21ee7_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_21ee7_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_21ee7_row3_col5" class="data row3 col5" >0.261580</td>
#       <td id="T_21ee7_row3_col6" class="data row3 col6" >0.260417</td>
#     </tr>
#     <tr>
#       <th id="T_21ee7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21ee7_row4_col0" class="data row4 col0" >25</td>
#       <td id="T_21ee7_row4_col1" class="data row4 col1" >google/flan-t5-small</td>
#       <td id="T_21ee7_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_21ee7_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_21ee7_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_21ee7_row4_col5" class="data row4 col5" >0.257440</td>
#       <td id="T_21ee7_row4_col6" class="data row4 col6" >0.243585</td>
#     </tr>
#   </tbody>
# </table>
# Prediction
# no     61479
# yes    27960
# Yes      561
# Name: count, dtype: int64

# %% [markdown]
# # Convert Text Predictions
#
# This code converts the LLM predictions stored in `classification_prompts.csv` to binary predictions. The process is applied to each model and the results are saved.

# %%
validation_ids = set(GiveMeSomeCredit.get_validation_row_ids())
display(responses_df.head())
group_columns = ["Model", "Description Column", "Classification Question ID"]
for (model,description_id,question_id),group_df in responses_df.groupby(group_columns):
    model_name = f"{model} D{description_id} Q{question_id}"
    display(HTML(f"<h1>{model_name}</h1>"))
    
    if not group_df["Row ID"].is_unique:
        raise ValueError("Duplicate Sample IDs found! Every Sample ID must be unique.")
        
    with pd.option_context("display.max_colwidth", None):
        display(
            group_df.head(5).style.set_properties(**{"text-align": "left"})
        )
        
    group_df = group_df.set_index("Row ID")
    
    missing_indices = validation_ids - set(group_df.index)
    if missing_indices:
        group_df = group_df.reindex(group_df.index.union(missing_indices))
    
    pred_clean = (
        group_df["Prediction"]
        .str.replace(r"[^\x00-\x7F]", "", regex=True)  # remove non-ASCII
        .str.upper()
        .str.strip()
    )
    
    pred_numeric = (
        pred_clean
        .map({"YES": 1, "NO": 0})
        .where(~pred_clean.isna(), -2)  # NaNs = -2
        .fillna(-1)                     # Anything else unmapped → -1
        .astype(int)
    )
    
    pred_probs = (
        group_df["Yes Probability"] /
        (group_df["Yes Probability"] + group_df["No Probability"])
    )
    
    predictions_df = pd.DataFrame(
        {
            "pred": pred_numeric,
            "pred_probs": pred_probs,
            "yes_prob": group_df["Yes Probability"],
            "no_prob": group_df["No Probability"],
        },
        index=group_df.index
    )[["pred", "pred_probs", "yes_prob", "no_prob"]]
    
    with pd.option_context("display.max_rows", 5, "display.max_columns", None):
        display(predictions_df)
    GiveMeSomeCredit.save_train_validation_results(model_name, predictions_df)
# Out:
#    Row ID                 Model  Description Column  \
# 0       4  google/flan-t5-small                   0
# 1      12  google/flan-t5-small                   0
# 2      14  google/flan-t5-small                   0
# 3      24  google/flan-t5-small                   0
# 4      25  google/flan-t5-small                   0
#
#    Classification Question ID Prediction  Yes Probability  No Probability
# 0                           0        yes         0.248806        0.226628
# 1                           0        yes         0.266791        0.234390
# 2                           0        yes         0.224461        0.160168
# 3                           0        yes         0.261580        0.260417
# 4                           0        yes         0.257440        0.243585
# <h1>google/flan-t5-small D0 Q0</h1>
# <style type="text/css">
# #T_335c1_row0_col0, #T_335c1_row0_col1, #T_335c1_row0_col2, #T_335c1_row0_col3, #T_335c1_row0_col4, #T_335c1_row0_col5, #T_335c1_row0_col6, #T_335c1_row1_col0, #T_335c1_row1_col1, #T_335c1_row1_col2, #T_335c1_row1_col3, #T_335c1_row1_col4, #T_335c1_row1_col5, #T_335c1_row1_col6, #T_335c1_row2_col0, #T_335c1_row2_col1, #T_335c1_row2_col2, #T_335c1_row2_col3, #T_335c1_row2_col4, #T_335c1_row2_col5, #T_335c1_row2_col6, #T_335c1_row3_col0, #T_335c1_row3_col1, #T_335c1_row3_col2, #T_335c1_row3_col3, #T_335c1_row3_col4, #T_335c1_row3_col5, #T_335c1_row3_col6, #T_335c1_row4_col0, #T_335c1_row4_col1, #T_335c1_row4_col2, #T_335c1_row4_col3, #T_335c1_row4_col4, #T_335c1_row4_col5, #T_335c1_row4_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_335c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_335c1_level0_col0" class="col_heading level0 col0" >Row ID</th>
#       <th id="T_335c1_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_335c1_level0_col2" class="col_heading level0 col2" >Description Column</th>
#       <th id="T_335c1_level0_col3" class="col_heading level0 col3" >Classification Question ID</th>
#       <th id="T_335c1_level0_col4" class="col_heading level0 col4" >Prediction</th>
#       <th id="T_335c1_level0_col5" class="col_heading level0 col5" >Yes Probability</th>
#       <th id="T_335c1_level0_col6" class="col_heading level0 col6" >No Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_335c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_335c1_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_335c1_row0_col1" class="data row0 col1" >google/flan-t5-small</td>
#       <td id="T_335c1_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_335c1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_335c1_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_335c1_row0_col5" class="data row0 col5" >0.248806</td>
#       <td id="T_335c1_row0_col6" class="data row0 col6" >0.226628</td>
#     </tr>
#     <tr>
#       <th id="T_335c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_335c1_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_335c1_row1_col1" class="data row1 col1" >google/flan-t5-small</td>
#       <td id="T_335c1_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_335c1_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_335c1_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_335c1_row1_col5" class="data row1 col5" >0.266791</td>
#       <td id="T_335c1_row1_col6" class="data row1 col6" >0.234390</td>
#     </tr>
#     <tr>
#       <th id="T_335c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_335c1_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_335c1_row2_col1" class="data row2 col1" >google/flan-t5-small</td>
#       <td id="T_335c1_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_335c1_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_335c1_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_335c1_row2_col5" class="data row2 col5" >0.224461</td>
#       <td id="T_335c1_row2_col6" class="data row2 col6" >0.160168</td>
#     </tr>
#     <tr>
#       <th id="T_335c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_335c1_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_335c1_row3_col1" class="data row3 col1" >google/flan-t5-small</td>
#       <td id="T_335c1_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_335c1_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_335c1_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_335c1_row3_col5" class="data row3 col5" >0.261580</td>
#       <td id="T_335c1_row3_col6" class="data row3 col6" >0.260417</td>
#     </tr>
#     <tr>
#       <th id="T_335c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_335c1_row4_col0" class="data row4 col0" >25</td>
#       <td id="T_335c1_row4_col1" class="data row4 col1" >google/flan-t5-small</td>
#       <td id="T_335c1_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_335c1_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_335c1_row4_col4" class="data row4 col4" >yes</td>
#       <td id="T_335c1_row4_col5" class="data row4 col5" >0.257440</td>
#       <td id="T_335c1_row4_col6" class="data row4 col6" >0.243585</td>
#     </tr>
#   </tbody>
# </table>
#         pred  pred_probs  yes_prob   no_prob
# Row ID
# 4          1    0.523325  0.248806  0.226628
# 12         1    0.532325  0.266791  0.234390
# ...      ...         ...       ...       ...
# 149992     1    0.522047  0.260023  0.238060
# 149993     1    0.521922  0.275122  0.252010
#
# [30000 rows x 4 columns]
# column:  ('google/flan-t5-small D0 Q0', 'pred')
# column:  ('google/flan-t5-small D0 Q0', 'pred_probs')
# column:  ('google/flan-t5-small D0 Q0', 'yes_prob')
# column:  ('google/flan-t5-small D0 Q0', 'no_prob')
# 2025-09-12 20:29:26,406 - INFO - Saved DataFrame to processed directory: /Users/rina/llm-classification/data/GiveMeSomeCredit/processed/training_results.csv
# 2025-09-12 20:29:26,617 - INFO - Saved DataFrame to processed directory: /Users/rina/llm-classification/data/GiveMeSomeCredit/processed/validation_results.csv
# <h1>google/flan-t5-small D0 Q1</h1>
# <style type="text/css">
# #T_b6e26_row0_col0, #T_b6e26_row0_col1, #T_b6e26_row0_col2, #T_b6e26_row0_col3, #T_b6e26_row0_col4, #T_b6e26_row0_col5, #T_b6e26_row0_col6, #T_b6e26_row1_col0, #T_b6e26_row1_col1, #T_b6e26_row1_col2, #T_b6e26_row1_col3, #T_b6e26_row1_col4, #T_b6e26_row1_col5, #T_b6e26_row1_col6, #T_b6e26_row2_col0, #T_b6e26_row2_col1, #T_b6e26_row2_col2, #T_b6e26_row2_col3, #T_b6e26_row2_col4, #T_b6e26_row2_col5, #T_b6e26_row2_col6, #T_b6e26_row3_col0, #T_b6e26_row3_col1, #T_b6e26_row3_col2, #T_b6e26_row3_col3, #T_b6e26_row3_col4, #T_b6e26_row3_col5, #T_b6e26_row3_col6, #T_b6e26_row4_col0, #T_b6e26_row4_col1, #T_b6e26_row4_col2, #T_b6e26_row4_col3, #T_b6e26_row4_col4, #T_b6e26_row4_col5, #T_b6e26_row4_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_b6e26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6e26_level0_col0" class="col_heading level0 col0" >Row ID</th>
#       <th id="T_b6e26_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_b6e26_level0_col2" class="col_heading level0 col2" >Description Column</th>
#       <th id="T_b6e26_level0_col3" class="col_heading level0 col3" >Classification Question ID</th>
#       <th id="T_b6e26_level0_col4" class="col_heading level0 col4" >Prediction</th>
#       <th id="T_b6e26_level0_col5" class="col_heading level0 col5" >Yes Probability</th>
#       <th id="T_b6e26_level0_col6" class="col_heading level0 col6" >No Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6e26_level0_row0" class="row_heading level0 row0" >30000</th>
#       <td id="T_b6e26_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_b6e26_row0_col1" class="data row0 col1" >google/flan-t5-small</td>
#       <td id="T_b6e26_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_b6e26_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_b6e26_row0_col4" class="data row0 col4" >no</td>
#       <td id="T_b6e26_row0_col5" class="data row0 col5" >0.451643</td>
#       <td id="T_b6e26_row0_col6" class="data row0 col6" >0.548016</td>
#     </tr>
#     <tr>
#       <th id="T_b6e26_level0_row1" class="row_heading level0 row1" >30001</th>
#       <td id="T_b6e26_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_b6e26_row1_col1" class="data row1 col1" >google/flan-t5-small</td>
#       <td id="T_b6e26_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_b6e26_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_b6e26_row1_col4" class="data row1 col4" >no</td>
#       <td id="T_b6e26_row1_col5" class="data row1 col5" >0.441889</td>
#       <td id="T_b6e26_row1_col6" class="data row1 col6" >0.557768</td>
#     </tr>
#     <tr>
#       <th id="T_b6e26_level0_row2" class="row_heading level0 row2" >30002</th>
#       <td id="T_b6e26_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_b6e26_row2_col1" class="data row2 col1" >google/flan-t5-small</td>
#       <td id="T_b6e26_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_b6e26_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_b6e26_row2_col4" class="data row2 col4" >no</td>
#       <td id="T_b6e26_row2_col5" class="data row2 col5" >0.459175</td>
#       <td id="T_b6e26_row2_col6" class="data row2 col6" >0.540490</td>
#     </tr>
#     <tr>
#       <th id="T_b6e26_level0_row3" class="row_heading level0 row3" >30003</th>
#       <td id="T_b6e26_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_b6e26_row3_col1" class="data row3 col1" >google/flan-t5-small</td>
#       <td id="T_b6e26_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_b6e26_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_b6e26_row3_col4" class="data row3 col4" >no</td>
#       <td id="T_b6e26_row3_col5" class="data row3 col5" >0.440042</td>
#       <td id="T_b6e26_row3_col6" class="data row3 col6" >0.559614</td>
#     </tr>
#     <tr>
#       <th id="T_b6e26_level0_row4" class="row_heading level0 row4" >30004</th>
#       <td id="T_b6e26_row4_col0" class="data row4 col0" >25</td>
#       <td id="T_b6e26_row4_col1" class="data row4 col1" >google/flan-t5-small</td>
#       <td id="T_b6e26_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_b6e26_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_b6e26_row4_col4" class="data row4 col4" >no</td>
#       <td id="T_b6e26_row4_col5" class="data row4 col5" >0.444551</td>
#       <td id="T_b6e26_row4_col6" class="data row4 col6" >0.555098</td>
#     </tr>
#   </tbody>
# </table>
#         pred  pred_probs  yes_prob   no_prob
# Row ID
# 4          0    0.451797  0.451643  0.548016
# 12         0    0.442041  0.441889  0.557768
# ...      ...         ...       ...       ...
# 149992     0    0.443931  0.443778  0.555879
# 149993     0    0.432476  0.432323  0.567323
#
# [30000 rows x 4 columns]
# column:  ('google/flan-t5-small D0 Q1', 'pred')
# column:  ('google/flan-t5-small D0 Q1', 'pred_probs')
# column:  ('google/flan-t5-small D0 Q1', 'yes_prob')
# column:  ('google/flan-t5-small D0 Q1', 'no_prob')
# 2025-09-12 20:29:27,281 - INFO - Saved DataFrame to processed directory: /Users/rina/llm-classification/data/GiveMeSomeCredit/processed/training_results.csv
# 2025-09-12 20:29:27,611 - INFO - Saved DataFrame to processed directory: /Users/rina/llm-classification/data/GiveMeSomeCredit/processed/validation_results.csv
# <h1>google/flan-t5-small D0 Q2</h1>
# <style type="text/css">
# #T_0a4c0_row0_col0, #T_0a4c0_row0_col1, #T_0a4c0_row0_col2, #T_0a4c0_row0_col3, #T_0a4c0_row0_col4, #T_0a4c0_row0_col5, #T_0a4c0_row0_col6, #T_0a4c0_row1_col0, #T_0a4c0_row1_col1, #T_0a4c0_row1_col2, #T_0a4c0_row1_col3, #T_0a4c0_row1_col4, #T_0a4c0_row1_col5, #T_0a4c0_row1_col6, #T_0a4c0_row2_col0, #T_0a4c0_row2_col1, #T_0a4c0_row2_col2, #T_0a4c0_row2_col3, #T_0a4c0_row2_col4, #T_0a4c0_row2_col5, #T_0a4c0_row2_col6, #T_0a4c0_row3_col0, #T_0a4c0_row3_col1, #T_0a4c0_row3_col2, #T_0a4c0_row3_col3, #T_0a4c0_row3_col4, #T_0a4c0_row3_col5, #T_0a4c0_row3_col6, #T_0a4c0_row4_col0, #T_0a4c0_row4_col1, #T_0a4c0_row4_col2, #T_0a4c0_row4_col3, #T_0a4c0_row4_col4, #T_0a4c0_row4_col5, #T_0a4c0_row4_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_0a4c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a4c0_level0_col0" class="col_heading level0 col0" >Row ID</th>
#       <th id="T_0a4c0_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_0a4c0_level0_col2" class="col_heading level0 col2" >Description Column</th>
#       <th id="T_0a4c0_level0_col3" class="col_heading level0 col3" >Classification Question ID</th>
#       <th id="T_0a4c0_level0_col4" class="col_heading level0 col4" >Prediction</th>
#       <th id="T_0a4c0_level0_col5" class="col_heading level0 col5" >Yes Probability</th>
#       <th id="T_0a4c0_level0_col6" class="col_heading level0 col6" >No Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a4c0_level0_row0" class="row_heading level0 row0" >60000</th>
#       <td id="T_0a4c0_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_0a4c0_row0_col1" class="data row0 col1" >google/flan-t5-small</td>
#       <td id="T_0a4c0_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0a4c0_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_0a4c0_row0_col4" class="data row0 col4" >no</td>
#       <td id="T_0a4c0_row0_col5" class="data row0 col5" >0.421418</td>
#       <td id="T_0a4c0_row0_col6" class="data row0 col6" >0.576574</td>
#     </tr>
#     <tr>
#       <th id="T_0a4c0_level0_row1" class="row_heading level0 row1" >60001</th>
#       <td id="T_0a4c0_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_0a4c0_row1_col1" class="data row1 col1" >google/flan-t5-small</td>
#       <td id="T_0a4c0_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0a4c0_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_0a4c0_row1_col4" class="data row1 col4" >no</td>
#       <td id="T_0a4c0_row1_col5" class="data row1 col5" >0.424796</td>
#       <td id="T_0a4c0_row1_col6" class="data row1 col6" >0.573229</td>
#     </tr>
#     <tr>
#       <th id="T_0a4c0_level0_row2" class="row_heading level0 row2" >60002</th>
#       <td id="T_0a4c0_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_0a4c0_row2_col1" class="data row2 col1" >google/flan-t5-small</td>
#       <td id="T_0a4c0_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_0a4c0_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_0a4c0_row2_col4" class="data row2 col4" >no</td>
#       <td id="T_0a4c0_row2_col5" class="data row2 col5" >0.446836</td>
#       <td id="T_0a4c0_row2_col6" class="data row2 col6" >0.551045</td>
#     </tr>
#     <tr>
#       <th id="T_0a4c0_level0_row3" class="row_heading level0 row3" >60003</th>
#       <td id="T_0a4c0_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_0a4c0_row3_col1" class="data row3 col1" >google/flan-t5-small</td>
#       <td id="T_0a4c0_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_0a4c0_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_0a4c0_row3_col4" class="data row3 col4" >no</td>
#       <td id="T_0a4c0_row3_col5" class="data row3 col5" >0.413422</td>
#       <td id="T_0a4c0_row3_col6" class="data row3 col6" >0.584450</td>
#     </tr>
#     <tr>
#       <th id="T_0a4c0_level0_row4" class="row_heading level0 row4" >60004</th>
#       <td id="T_0a4c0_row4_col0" class="data row4 col0" >25</td>
#       <td id="T_0a4c0_row4_col1" class="data row4 col1" >google/flan-t5-small</td>
#       <td id="T_0a4c0_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_0a4c0_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_0a4c0_row4_col4" class="data row4 col4" >no</td>
#       <td id="T_0a4c0_row4_col5" class="data row4 col5" >0.421743</td>
#       <td id="T_0a4c0_row4_col6" class="data row4 col6" >0.576147</td>
#     </tr>
#   </tbody>
# </table>
#         pred  pred_probs  yes_prob   no_prob
# Row ID
# 4          0    0.422266  0.421418  0.576574
# 12         0    0.425637  0.424796  0.573229
# ...      ...         ...       ...       ...
# 149992     0    0.422996  0.422142  0.575839
# 149993     0    0.419075  0.418228  0.579752
#
# [30000 rows x 4 columns]
# column:  ('google/flan-t5-small D0 Q2', 'pred')
# column:  ('google/flan-t5-small D0 Q2', 'pred_probs')
# column:  ('google/flan-t5-small D0 Q2', 'yes_prob')
# column:  ('google/flan-t5-small D0 Q2', 'no_prob')
# 2025-09-12 20:29:28,312 - INFO - Saved DataFrame to processed directory: /Users/rina/llm-classification/data/GiveMeSomeCredit/processed/training_results.csv
# 2025-09-12 20:29:28,762 - INFO - Saved DataFrame to processed directory: /Users/rina/llm-classification/data/GiveMeSomeCredit/processed/validation_results.csv

# %% [markdown]
# # Check Results

# %%
display(
    *GiveMeSomeCredit.load_training_validation_results()
)
# Out:
#        Logistic Regression            Random Forest             \
#                       pred pred_probs          pred pred_probs
# Row ID
# 1                        1   0.756797             1       0.71
# 2                        0   0.464318             0       0.03
# 3                        1   0.707312             0       0.10
# 5                        0   0.209631             0       0.08
# 6                        0   0.249206             0       0.01
# ...                    ...        ...           ...        ...
# 149996                   0   0.243774             0       0.00
# 149997                   0   0.451480             0       0.00
# 149998                   0   0.298296             0       0.00
# 149999                   1   0.504252             0       0.00
# 150000                   0   0.288816             0       0.00
#
#        Histogram-Based Gradient Boosting
#                                     pred pred_probs
# Row ID
# 1                                      0   0.342372
# 2                                      0   0.089232
# 3                                      0   0.320130
# 5                                      0   0.124813
# 6                                      0   0.008083
# ...                                  ...        ...
# 149996                                 0   0.004548
# 149997                                 0   0.020155
# 149998                                 0   0.016222
# 149999                                 0   0.010798
# 150000                                 0   0.020499
#
# [120000 rows x 6 columns]
#        Logistic Regression            Random Forest             \
#                       pred pred_probs          pred pred_probs
# Row ID
# 4                        1   0.518869             0       0.00
# 12                       0   0.413919             0       0.00
# 14                       1   0.947342             1       0.63
# 24                       0   0.476525             0       0.00
# 25                       0   0.340831             0       0.03
# ...                    ...        ...           ...        ...
# 149984                   0   0.180238             0       0.00
# 149985                   0   0.170122             0       0.00
# 149987                   0   0.386821             0       0.03
# 149992                   0   0.309497             0       0.00
# 149993                   0   0.391706             0       0.01
#
#        Histogram-Based Gradient Boosting             \
#                                     pred pred_probs
# Row ID
# 4                                      0   0.022168
# 12                                     0   0.013772
# 14                                     1   0.618585
# 24                                     0   0.014112
# 25                                     0   0.009455
# ...                                  ...        ...
# 149984                                 0   0.005129
# 149985                                 0   0.005574
# 149987                                 0   0.025807
# 149992                                 0   0.012891
# 149993                                 0   0.063988
#
#        google/flan-t5-small D0 Q0                                 \
#                              pred pred_probs  yes_prob   no_prob
# Row ID
# 4                               1   0.523325  0.248806  0.226628
# 12                              1   0.532325  0.266791  0.234390
# 14                              1   0.583578  0.224461  0.160168
# 24                              1   0.501114  0.261580  0.260417
# 25                              1   0.513826  0.257440  0.243585
# ...                           ...        ...       ...       ...
# 149984                          1   0.511567  0.266742  0.254680
# 149985                          1   0.507404  0.279580  0.271420
# 149987                          1   0.529707  0.288262  0.255930
# 149992                          1   0.522047  0.260023  0.238060
# 149993                          1   0.521922  0.275122  0.252010
#
#        google/flan-t5-small D0 Q1                                 \
#                              pred pred_probs  yes_prob   no_prob
# Row ID
# 4                               0   0.451797  0.451643  0.548016
# 12                              0   0.442041  0.441889  0.557768
# 14                              0   0.459329  0.459175  0.540490
# 24                              0   0.440193  0.440042  0.559614
# 25                              0   0.444707  0.444551  0.555098
# ...                           ...        ...       ...       ...
# 149984                          0   0.446341  0.446193  0.553476
# 149985                          0   0.435533  0.435390  0.564281
# 149987                          0   0.454778  0.454623  0.545038
# 149992                          0   0.443931  0.443778  0.555879
# 149993                          0   0.432476  0.432323  0.567323
#
#        google/flan-t5-small D0 Q2
#                              pred pred_probs  yes_prob   no_prob
# Row ID
# 4                               0   0.422266  0.421418  0.576574
# 12                              0   0.425637  0.424796  0.573229
# 14                              0   0.447785  0.446836  0.551045
# 24                              0   0.414304  0.413422  0.584450
# 25                              0   0.422635  0.421743  0.576147
# ...                           ...        ...       ...       ...
# 149984                          0   0.414935  0.414106  0.583897
# 149985                          0   0.415646  0.414839  0.583221
# 149987                          0   0.426753  0.425915  0.572120
# 149992                          0   0.422996  0.422142  0.575839
# 149993                          0   0.419075  0.418228  0.579752
#
# [30000 rows x 18 columns]
